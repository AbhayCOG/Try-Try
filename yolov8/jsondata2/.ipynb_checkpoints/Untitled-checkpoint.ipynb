# %%
import pandas as pd
import cv2
import numpy as np
import os
import shutil
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf

# %%
p1 = "train/"
p2 = "train/train/images"

# %%
lis = os.listdir(p1)

# %%
lis = lis[1:]

# %%
# lis

# %%
for i in lis:
  if str(i).endswith(".tif"):
    image = f"{p1}{str(i)}"
    shutil.copy(image, f"{p2}{str(i)}")
    # shutil.copy(f"{p2}{str(i)}",f"{p3}{str(i)}")

# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/699.2 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/699.2 kB 1.6 MB/s eta 0:00:01
#    -------- ------------------------------- 143.4/699.2 kB 1.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 204.8/699.2 kB 1.6 MB/s eta 0:00:01
#    ------------------ --------------------- 327.7/699.2 kB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 471.0/699.2 kB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 553.0/699.2 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 699.2/699.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#    ---------------------------------------- 0.2/192.3 MB 5.0 MB/s eta 0:00:39
#    ---------------------------------------- 0.5/192.3 MB 7.9 MB/s eta 0:00:25
# ...

# %%
from ultralytics import YOLO
model = YOLO("last (3).pt")
model.predict("temst/TCGA_DU_7008_19830723_30.tif",show=True,conf=0.6,visualize=True,save=False,show_labels=True,show_conf=True)
# Out:
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage0_Conv_features.png... (32/64)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage1_Conv_features.png... (32/128)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage2_C2f_features.png... (32/128)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage3_Conv_features.png... (32/256)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage4_C2f_features.png... (32/256)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage5_Conv_features.png... (32/512)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage6_C2f_features.png... (32/512)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage7_Conv_features.png... (32/512)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage8_C2f_features.png... (32/512)
# Saving runs\segment\predict2\TCGA_DU_7008_19830723_30\stage9_SPPF_features.png... (32/512)
# ...

# %%
# !yolo help
# Out:
# 'yolo' is not recognized as an internal or external command,
# operable program or batch file.
